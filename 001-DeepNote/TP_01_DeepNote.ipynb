# %% [markdown]
# # TP01 \- Deepnote Franco Arnaudin

# %% [markdown]
# Soy Franco Arnaudin, tengo 26 años, me dedico a la ingeniería de datos hace más de 3 años y quiero acreditar mis conocimientos de madera formal haciendo la tecnicatura\.

# %% [markdown]
# Mis expectativas de la materia son poder aprender cosas nuevas, repasar los fundamentos que ya tengo incorporados y ayudar a mis compañeros y aconsejarlos en su camino profesional\.

# %%
print("Mi primer notebook de Deepnote")
# Out:
# Mi primer notebook de Deepnote

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5c55dd23-c462-402e-91cc-9765b1e5bb18' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' />
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
